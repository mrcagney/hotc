# %%
import sys

import pandas as pd

sys.path.append('../')

import hotc_getter as hg

# %load_ext autoreload
# %autoreload 2

# %%
# Print counter locations

hg.COUNTERS
# Out:
#    location_code               location_name  \
# 0           CL15      1 Courthouse Lane (NS)
# 1           CL14            107 Quay St (EW)
# 2           CL19             150 K Road (EW)
# 3            CL6             183 K Road (EW)
# 4           CL20        19 Shortland St (EW)
# 5           CL21              2 High St (NS)
# 6           CL10           205 Queen St (EW)
# 7            CL5           210 Queen St (NS)
# 8            CL4           261 Queen St (NS)
# 9           CL22           297 Queen St (NS)
# 10          CL18            30 Queen St (NS)
# 11           CL3            45 Queen St (NS)
# 12           CL2             59 High St (NS)
# 13          CL23          61 Federal St (NS)
# 14          CL17       7 Custom St East (EW)
# 15           CL8             8 Darby St (EW)
# 16           CL7             8 Darby St (NS)
# 17          CL13       Commerce St West (NS)
# 18           CL9  Te Ara Tahuhu Walkway (EW)
#
# ...

# %%
# Get daily counts for 2017-10

dates = pd.date_range('2017-10-01', '2017-10-31', period='D')
dates = [date.strftime(hg.DATE_FORMAT) for date in dates]
print(dates)

# %time hotc_by_date = hg.get_hotc(dates, 'day')

print(list(hotc_by_date.keys()))
hotc_by_date[dates[0]]
# Out:
# ['2017-10-01', '2017-10-02', '2017-10-03', '2017-10-04', '2017-10-05', '2017-10-06', '2017-10-07', '2017-10-08', '2017-10-09', '2017-10-10', '2017-10-11', '2017-10-12', '2017-10-13', '2017-10-14', '2017-10-15', '2017-10-16', '2017-10-17', '2017-10-18', '2017-10-19', '2017-10-20', '2017-10-21', '2017-10-22', '2017-10-23', '2017-10-24', '2017-10-25', '2017-10-26', '2017-10-27', '2017-10-28', '2017-10-29', '2017-10-30', '2017-10-31']
# CPU times: user 8.57 s, sys: 100 ms, total: 8.67 s
# Wall time: 36.6 s
# ['2017-10-30', '2017-10-27', '2017-10-28', '2017-10-02', '2017-10-16', '2017-10-21', '2017-10-11', '2017-10-22', '2017-10-24', '2017-10-18', '2017-10-25', '2017-10-04', '2017-10-07', '2017-10-19', '2017-10-01', '2017-10-23', '2017-10-08', '2017-10-05', '2017-10-14', '2017-10-03', '2017-10-12', '2017-10-15', '2017-10-29', '2017-10-26', '2017-10-31', '2017-10-20', '2017-10-13', '2017-10-10', '2017-10-06', '2017-10-09', '2017-10-17']
# ...

# %%
# Get daily counts for 2017-10

dates = pd.date_range('2017-10-01', '2017-10-15', period='D')
dates = [date.strftime(hg.DATE_FORMAT) for date in dates]
print(dates)

# %time hotc_by_date = hg.get_hotc(dates, 'week')

print(list(hotc_by_date.keys()))
hotc_by_date[dates[0]]
# Out:
# ['2017-10-01', '2017-10-02', '2017-10-03', '2017-10-04', '2017-10-05', '2017-10-06', '2017-10-07', '2017-10-08', '2017-10-09', '2017-10-10', '2017-10-11', '2017-10-12', '2017-10-13', '2017-10-14', '2017-10-15', '2017-10-16', '2017-10-17', '2017-10-18', '2017-10-19', '2017-10-20', '2017-10-21', '2017-10-22', '2017-10-23', '2017-10-24', '2017-10-25', '2017-10-26', '2017-10-27', '2017-10-28', '2017-10-29', '2017-10-30', '2017-10-31']
# CPU times: user 3.49 s, sys: 40 ms, total: 3.53 s
# Wall time: 32.9 s
# ['2017-10-30', '2017-10-27', '2017-10-28', '2017-10-02', '2017-10-16', '2017-10-21', '2017-10-11', '2017-10-22', '2017-10-24', '2017-10-18', '2017-10-25', '2017-10-04', '2017-10-07', '2017-10-19', '2017-10-01', '2017-10-23', '2017-10-08', '2017-10-05', '2017-10-14', '2017-10-03', '2017-10-12', '2017-10-15', '2017-10-29', '2017-10-26', '2017-10-31', '2017-10-20', '2017-10-13', '2017-10-10', '2017-10-06', '2017-10-09', '2017-10-17']
# ...
